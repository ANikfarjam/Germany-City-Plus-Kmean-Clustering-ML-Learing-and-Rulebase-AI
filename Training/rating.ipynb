# %% [markdown]
# Author: Ryan Fernald

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/chuck/Documents/GitHub/CS133FinalProject/CS133Project/DATA/Sean data - help/Cultural/germany_state_ratings_1-10_various_categories.csv')
df.drop(['Country', 'Code'], axis = 1, inplace=True)
df.info()
df.set_index("State")
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      16 non-null     object
#  1   Education                  16 non-null     float64
#  2   Jobs                       16 non-null     float64
#  3   Income                     16 non-null     float64
#  4   Safety                     16 non-null     float64
#  5   Health                     16 non-null     float64
#  6   Environment                16 non-null     float64
#  7   Civic engagement           16 non-null     float64
#  8   Accessibility to services  16 non-null     float64
#  9   Housing                    16 non-null     float64
#  10  Community                  16 non-null     float64
#  11  Life satisfaction          16 non-null     float64
# dtypes: float64(11), object(1)
# memory usage: 1.6+ KB
#                      State  Education  Jobs  Income  Safety  Health  \
# 0        Baden-Württemberg        8.0   9.5     5.1     9.8     8.0
# 1                  Bavaria        8.8   9.8     5.2     9.8     7.5
# 2                   Berlin        8.6   8.0     4.1     9.7     7.1
# 3              Brandenburg        9.5   9.4     4.1     9.9     6.7
# 4                   Bremen        7.2   7.5     4.2     9.7     6.2
# 5                  Hamburg        8.4   8.7     5.1     9.7     7.3
# 6                    Hesse        7.8   8.6     4.8     9.7     7.3
# 7   Mecklenburg-Vorpommern        9.4   9.1     3.9     9.8     6.5
# 8             Lower Saxony        7.9   9.1     4.4     9.8     6.7
# 9   North Rhine-Westphalia        7.7   8.3     4.5     9.9     6.7
# 10    Rhineland-Palatinate        8.0   8.9     4.6     9.9     7.0
# 11                Saarland        8.0   8.8     4.1     9.7     6.2
# 12                  Saxony        9.9   9.4     4.0     9.8     6.8
# 13           Saxony-Anhalt        9.5   8.7     3.9     9.5     5.7
# 14      Schleswig-Holstein        8.7   9.2     4.6     9.8     7.0
# 15               Thuringia        9.7   9.4     3.9     9.8     6.5
#
#     Environment  Civic engagement  Accessibility to services  Housing  \
# 0           7.6               7.7                        6.6      4.6
# 1           7.5               8.1                        6.6      4.6
# 2           5.8               7.1                        7.2      5.1
# 3           7.0               7.2                        5.7      5.7
# 4           6.4               6.3                        6.4      5.1
# 5           7.1               7.7                        7.2      5.1
# 6           7.7               7.3                        6.9      4.6
# 7           7.7               6.2                        5.2      6.2
# 8           7.6               7.0                        6.4      5.1
# 9           6.9               7.4                        6.8      5.1
# 10          8.1               7.5                        6.5      5.1
# 11          8.0               7.6                        5.7      5.1
# 12          7.2               7.4                        5.9      6.2
# 13          7.3               5.4                        4.9      6.8
# 14          7.7               7.7                        7.0      5.7
# 15          7.6               7.0                        5.2      6.2
#
#     Community  Life satisfaction
# 0         5.3                8.5
# 1         5.2                7.7
# 2         8.0                7.3
# 3         6.9                8.1
# 4         7.3                4.6
# 5         3.9                8.8
# 6         7.1                6.2
# 7         8.5                7.7
# 8         6.8                8.8
# 9         6.0                8.5
# 10        7.2                8.1
# 11        9.9                8.1
# 12        6.4                6.9
# 13        5.3                7.7
# 14        4.1                8.5
# 15        9.3                8.1

# %%
# Extract the first cell from the second column (excluding the 'Region' column)
first_cell_value = df.iloc[0, 1]  
print("First cell value from the second column:", first_cell_value)

# Generate a list of 100 values centered around that value with a normal distribution
new_values = np.random.normal(first_cell_value, scale=0.5, size=100)
print("List of 20 values centered around the first cell value with a normal distribution:")
print(new_values)
# Out:
# First cell value from the second column: 8.0
# List of 20 values centered around the first cell value with a normal distribution:
# [9.0730236  7.28123107 8.11197307 7.96953498 8.27662722 8.49208437
#  7.55158042 7.92660267 7.57840322 8.90360356 7.44643746 7.7478164
#  8.35161684 8.63513712 8.1975256  7.36723288 7.85121719 7.62404177
#  7.9909614  8.04796486 7.6023675  7.91769274 7.52534951 7.96348202
#  8.45756995 7.90307259 7.52200418 8.03834718 7.34821466 8.41677537
#  7.89799832 7.93500654 8.23455001 7.97479871 7.73824881 8.72899223
#  7.63175926 8.07854434 8.10522708 8.05829071 8.19543678 8.81518313
#  7.61318834 7.74654772 7.22560404 8.65091935 7.74310113 8.06949266
#  7.68490784 7.65283552 7.80001732 8.2742025  8.01903652 7.54098063
#  7.92887665 7.38785411 7.52141245 7.81413697 7.59191774 7.46341864
#  8.61598792 8.12238953 7.74809497 7.65685584 7.95923007 9.65589805
#  8.97323247 7.77861028 8.49224223 8.09559266 7.50736648 8.32300591
#  7.44853568 7.98809122 7.45369821 8.65774693 8.17274945 8.17168417
#  8.73530929 8.31901052 7.5062578  8.07624854 8.52824787 7.24806437
#  7.86234661 7.38180412 9.42056872 7.94165466 8.05499152 8.34023929
#  7.55990307 8.99515953 8.70114473 7.64473207 8.56213398 8.39111113
#  7.56594607 7.36887925 7.61268088 7.73584224]

# %%
new_dfs = []
replication_index = 4000

for i , original_row in df.iterrows():

    new_rows = []

    for j in range(replication_index):
        new_values = {}
        for column, original_value in original_row.items():
            if column == 'State':
                continue
            new_value = np.random.normal(original_value, scale=0.5)
            new_values[column] = new_value

        new_rows.append(new_values)
    new_df = pd.DataFrame(new_rows)
    new_df['State'] = original_row['State']
    new_dfs.append(new_df)

merged_df = pd.concat(new_dfs, ignore_index=True)
merged_df.set_index('State', inplace=True)
merged_df.reset_index(inplace=True)
merged_df.to_csv('resampling_4000.csv', index=False)
merged_df.info()
merged_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64000 entries, 0 to 63999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      64000 non-null  object
#  1   Education                  64000 non-null  float64
#  2   Jobs                       64000 non-null  float64
#  3   Income                     64000 non-null  float64
#  4   Safety                     64000 non-null  float64
#  5   Health                     64000 non-null  float64
#  6   Environment                64000 non-null  float64
#  7   Civic engagement           64000 non-null  float64
#  8   Accessibility to services  64000 non-null  float64
#  9   Housing                    64000 non-null  float64
#  10  Community                  64000 non-null  float64
#  11  Life satisfaction          64000 non-null  float64
# dtypes: float64(11), object(1)
# memory usage: 5.9+ MB
#                    State  Education       Jobs    Income     Safety    Health  \
# 0      Baden-Württemberg   7.940059   9.197511  5.351490   9.562006  8.141710
# 1      Baden-Württemberg   8.447812   9.442409  5.454483  10.054438  8.383084
# 2      Baden-Württemberg   8.376195   9.481738  5.534053   8.614922  7.598558
# 3      Baden-Württemberg   7.996578   9.289316  4.987552  10.543838  8.064021
# 4      Baden-Württemberg   7.485998   9.389754  5.170968   9.838613  7.807292
# ...                  ...        ...        ...       ...        ...       ...
# 63995          Thuringia  10.443509   9.401656  4.081816   9.753362  6.060328
# 63996          Thuringia   9.488043  10.111185  4.813914   9.831382  5.870522
# 63997          Thuringia   9.288855   8.757577  3.369126   8.228497  5.578688
# 63998          Thuringia   9.662946   9.424187  4.248020  10.298207  6.098981
# 63999          Thuringia   9.559486   9.606886  5.087570  10.392875  6.618976
#
#        Environment  Civic engagement  Accessibility to services   Housing  \
# 0         7.818456          7.765946                   6.900958  4.992455
# 1         7.560623          7.612625                   5.999105  5.063640
# 2         7.050402          7.131123                   6.799396  4.236480
# 3         7.720748          7.811655                   6.804208  5.808555
# 4         6.899547          7.385090                   6.693467  5.187894
# ...            ...               ...                        ...       ...
# 63995     7.296285          7.005776                   5.535612  6.166081
# 63996     7.356943          6.475898                   4.146770  6.325928
# 63997     7.810276          7.206337                   5.271477  6.518730
# 63998     7.999004          6.647486                   5.547187  5.616789
# 63999     6.970635          6.471562                   5.151229  6.651643
#
#        Community  Life satisfaction
# 0       5.447094           8.266810
# 1       5.531982           8.968268
# 2       5.278436           8.657714
# 3       5.144227           8.179010
# 4       4.542646           7.750564
# ...          ...                ...
# 63995   8.028584           8.101655
# 63996   8.980506           7.324774
# 63997   9.187685           8.293106
# 63998   9.268481           7.816163
# 63999   8.625846           8.625283
#
# [64000 rows x 12 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=merged_df[merged_df['State'] == 'Schleswig-Holstein'], x='Community', label='Schleswig-Holstein')
sns.histplot(data=merged_df[merged_df['State'] == 'Saarland'], x='Community', label='Saarland')
sns.histplot(data=merged_df[merged_df['State'] == 'North Rhine-Westphalia'], x='Community', label='North Rhine-Westphalia')

plt.legend()
plt.show()
# Out:
# /Users/chuck/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/chuck/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/chuck/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/chuck/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/chuck/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/chuck/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
specific_rows = merged_df.loc[(merged_df['State'] == 'Schleswig-Holstein') | (merged_df['State'] == 'Bavaria')]

specific_rows
# Out:
#                     State  Education       Jobs    Income     Safety  \
# 4000              Bavaria   8.481684   9.368919  4.191032   9.160578
# 4001              Bavaria   9.171147   9.515681  4.968258   9.537496
# 4002              Bavaria   9.626755   8.645618  5.462300  10.224972
# 4003              Bavaria   8.822006   9.988736  4.551331  10.039169
# 4004              Bavaria   7.991882  10.541952  5.370485   9.463362
# ...                   ...        ...        ...       ...        ...
# 59995  Schleswig-Holstein   8.842075   9.311492  4.782098  10.247751
# 59996  Schleswig-Holstein   9.405193   9.589051  5.067633   9.441642
# 59997  Schleswig-Holstein   9.255881   8.534068  5.073552  10.515570
# 59998  Schleswig-Holstein   8.411992   9.858281  4.088276   9.602853
# 59999  Schleswig-Holstein   8.781381   8.940678  3.958078  10.646027
#
#          Health  Environment  Civic engagement  Accessibility to services  \
# 4000   8.062457     8.050046          7.909686                   6.560329
# 4001   7.202026     7.782912          8.722658                   6.651548
# 4002   6.807464     8.410032          7.739272                   7.476608
# 4003   7.135336     7.800670          7.899440                   6.278266
# 4004   8.245884     7.634110          7.578475                   6.318320
# ...         ...          ...               ...                        ...
# 59995  6.952412     8.261955          8.471049                   6.416180
# 59996  6.089084     7.465739          7.801871                   5.955006
# 59997  7.419395     7.540251          8.054459                   7.132028
# 59998  7.021260     7.020119          6.790737                   7.207974
# 59999  5.929776     7.639970          7.640844                   6.607606
#
#         Housing  Community  Life satisfaction
# 4000   4.881275   5.659858           6.980476
# 4001   4.605279   5.703602           7.119898
# 4002   3.863202   4.877636           7.568013
# 4003   5.181977   4.560945           6.962394
# 4004   3.987490   5.271604           6.900821
# ...         ...        ...                ...
# 59995  5.908634   4.417915           8.784241
# 59996  5.937751   2.892246           8.653859
# 59997  6.100300   3.818003           8.517796
# 59998  5.977138   4.502688           8.426342
# 59999  5.295744   4.579739           7.988867
#
# [8000 rows x 12 columns]
