# %%
import pandas as pd

politics = pd.read_csv("./politics.csv", encoding="utf-16", sep="\t")
politics
# Out:
#     Party                                                                                  \
# 0    AfD - Alternative for Germany (Alternative für...
# 1    AfD - Alternative for Germany (Alternative für...
# 2    AfD - Alternative for Germany (Alternative für...
# 3    CDU - Christian Democratic Union (Christlich D...
# 4    CDU - Christian Democratic Union (Christlich D...
# ..                                                 ...
# 97   SPD - Social Democrats (Sozialdemokratische Pa...
# 98   SPD - Social Democrats (Sozialdemokratische Pa...
# 99   SPD - Social Democrats (Sozialdemokratische Pa...
# 100  SPD - Social Democrats (Sozialdemokratische Pa...
# 101  SPD - Social Democrats (Sozialdemokratische Pa...
#
#      Date        # of Seats   % of Seats   # of Votes   % of Votes
# 0    22-Sep-13             0         0.00      2052372        4.70
# 1    24-Sep-17            94        13.26      5878115       12.64
# 2    26-Sep-21            83        11.30      4803902       10.30
# ...
