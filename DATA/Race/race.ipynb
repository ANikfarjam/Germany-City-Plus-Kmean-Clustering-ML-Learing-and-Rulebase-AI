# %% [markdown]
# Data from 2022

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

url = "https://en.wikipedia.org/wiki/Demographics_of_Germany"
response = requests.get(url)

if response.status_code == 200:
    health_soup = BeautifulSoup(response.content, 'html.parser')
else:
    print("Couldn't reach", url)

# %%
with open("racial_demograpihcs.html", 'w') as file:
    file.write(health_soup.prettify())

# %%
foreign_nationals_table = health_soup.find('table', class_='wikitable mw-collapsible')

if foreign_nationals_table:
    print(foreign_nationals_table)
    rows = [row for row in foreign_nationals_table.find_all('tr') if not row.find('flagicon')]
    rank_list = []
    nationality_list = []
    population_list = []

    for row in rows:
        # Find all table data elements in the row
        cells = row.find_all('td')

        # Extract data if there are enough cells in the row
        if len(cells) == 3:
            # Extracting data from cells
            nation_text = None

            # Find the <a> tag directly skipping the <span> with class 'flagicon'
            nation_tag = cells[1].find('a')
            if nation_tag:
                nation_text = nation_tag.get_text(strip=True)

            rank = cells[0].get_text(strip=True)
            population = cells[2].get_text(strip=True)

            # Append data to respective lists
            rank_list.append(rank)
            nationality_list.append(nation_text)
            population_list.append(population)
else:
    print("Foreign nationals table not found.")
# Out:
# <table class="wikitable mw-collapsible">
# <tbody><tr>
# <th style="background:#efefef;">Rank
# </th>
# <th style="background:#efefef;">Nationality
# </th>
# <th style="background:#efefef;">Population (31.12.2022)
# </th></tr>
# <tr>
# <td></td>
# <td>Total</td>
# <td>13,383,910
# </td></tr>
# <tr>
# <td>1</td>
# <td><span class="flagicon"><span class="mw-image-border" typeof="mw:File"><span><img alt="" class="mw-file-element" data-file-height="800" data-file-width="1200" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Flag_of_Turkey.svg/23px-Flag_of_Turkey.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Flag_of_Turkey.svg/35px-Flag_of_Turkey.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Flag_of_Turkey.svg/45px-Flag_of_Turkey.svg.png 2x" width="23"/></span></span> </span><a href="/wiki/Turkey" title="Turkey">Turkey</a></td>
# <td>1,487,110
# </td></tr>
# <tr>
# <td>2</td>
# ...

# %%
immigration_df = pd.DataFrame({'Rank': rank_list, 
                              'Nationality': nationality_list,
                              'Population': population_list}) 

immigration_df
# Out:
#    Rank             Nationality  Population
# 0                          None  13,383,910
# 1     1                  Turkey   1,487,110
# 2     2                 Ukraine   1,164,200
# 3     3                   Syria     923,805
# 4     4                             883,670
# 5     5                             880,780
# 6     6                             644,970
# 7     7                             436,325
# 8     8                             429,665
# 9     9             Afghanistan     377,240
# 10   10                             361,270
# 11   11                  Russia     290,615
# 12   12                    Iraq     284,595
# 13   13                  Kosovo     280,850
# 14   14                  Serbia     251,365
# 15   15  Bosnia and Herzegovina     233,775
# 16   16                             214,695
# 17   17                   India     210,385
# 18   18                             193,460
# 19   19                             185,755
# ...

# %%
# Out:
# [None,
#  'Turkey',
#  'Ukraine',
#  'Syria',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Afghanistan',
#  '',
#  'Russia',
#  'Iraq',
#  'Kosovo',
#  'Serbia',
#  'Bosnia and Herzegovina',
#  '',
#  'India',
#  '',
#  '',
#  '',
#  'China',
#  'North Macedonia',
#  'Iran',
#  '',
#  '',
#  'United States',
#  'Vietnam',
#  'Albania',
#  'Morocco',
#  'United Kingdom']

# %% [markdown]
# At this point I discovered a better way to get data
